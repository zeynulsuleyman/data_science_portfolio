# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_2021 = pd.read_csv("world-happiness-report-2021.csv")
df_history = pd.read_csv("world-happiness-report.csv")

# %%
df_2021
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df_history
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_2021.shape
# Out:
# (149, 20)

# %%
df_history.shape
# Out:
# (1949, 11)

# %%
df_history.head(1)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724                7.37           0.451
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.8                         0.718       0.168
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258

# %%
df_2021.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904          7.78
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
# ...

# %%
df_history.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
history_df = df_history[['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
       'Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']].copy()

# %%
history_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
history_df.shape
# Out:
# (1949, 9)

# %%
df_2021
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df1_2021 = df_2021[['Country name', 'Regional indicator', 'Ladder score','Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity','Perceptions of corruption']]

# %%
df1_2021.head(1)
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186

# %%
history_df.head(1)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724                7.37           0.451
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.8                         0.718       0.168
#
#    Perceptions of corruption
# 0                      0.882

# %%
df1_2021.rename(columns={"Ladder score":"Life Ladder","Logged GDP per capita":"Log GDP per capita","Healthy life expectancy":"Healthy life expectancy at birth"}, inplace=True)
# Out:
# C:\Users\ContraVolta\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df1_2021.head(1)
# Out:
#   Country name Regional indicator  Life Ladder  Log GDP per capita  \
# 0      Finland     Western Europe        7.842              10.775
#
#    Social support  Healthy life expectancy at birth  \
# 0           0.954                              72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.949      -0.098                      0.186

# %%
history_df.head(1)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724                7.37           0.451
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.8                         0.718       0.168
#
#    Perceptions of corruption
# 0                      0.882

# %%
df1_2021["year"]=2021
# Out:
# <ipython-input-26-8e1545597b7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2021["year"]=2021

# %%
df1_2021.sample(5)
# Out:
#                  Country name                  Regional indicator  \
# 126                    Jordan        Middle East and North Africa
# 23   Taiwan Province of China                           East Asia
# 34                     Brazil         Latin America and Caribbean
# 77                 Tajikistan  Commonwealth of Independent States
# 64                    Moldova  Commonwealth of Independent States
#
#      Life Ladder  Log GDP per capita  Social support  \
# 126        4.395               9.182           0.767
# 23         6.584              10.871           0.898
# 34         6.330               9.577           0.882
# 77         5.466               8.091           0.860
# 64         5.766               9.454           0.857
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 126                            67.000                         0.755
# 23                             69.600                         0.784
# ...

# %%
history_df.head(2)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724                7.37           0.451
# 1  Afghanistan  2009        4.402                7.54           0.552
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.8                         0.718       0.168
# 1                              51.2                         0.679       0.190
#
#    Perceptions of corruption
# 0                      0.882
# 1                      0.850

# %%
history_df["Regional indicator"]=df1_2021["Regional indicator"]

# %%
df1_2021["Regional indicator"].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Central and Eastern Europe            17
# Middle East and North Africa          17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
df_sub_saharan = list(df1_2021[df1_2021["Regional indicator"] == "Sub-Saharan Africa"]["Country name"])

# %%
df_west = list(df1_2021[df1_2021["Regional indicator"] == "Western Europe"]["Country name"])

# %%
df_middle_east=df1_2021[df1_2021['Regional indicator']=='Middle East and North Africa']

# %%
df_central=df1_2021[df1_2021['Regional indicator']=='Central and Eastern Europe']

# %%
df_commonwealth=df1_2021[df1_2021['Regional indicator']=='Commonwealth of Independent States']

# %%
df_Southeast=df1_2021[df1_2021['Regional indicator']=='Southeast Asia']

# %%
df_South=df1_2021[df1_2021['Regional indicator']=='South Asia']

# %%
df_East=df1_2021[df1_2021['Regional indicator']=='East Asia']

# %%
df_north = df1_2021[df1_2021['Regional indicator']=='North America and ANZ']

# %%
df_latin = df1_2021[df1_2021["Regional indicator"] == "Latin America and Caribbean"]
df_latin["Country name"].to_list()
# Out:
# ['Costa Rica',
#  'Guatemala',
#  'Uruguay',
#  'Brazil',
#  'Mexico',
#  'Jamaica',
#  'Panama',
#  'Chile',
#  'El Salvador',
#  'Colombia',
#  'Nicaragua',
#  'Argentina',
#  'Honduras',
#  'Peru',
#  'Ecuador',
#  'Bolivia',
#  'Paraguay',
#  'Dominican Republic',
#  'Venezuela',
#  'Haiti']

# %%
df1_2021["Regional indicator"].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Central and Eastern Europe            17
# Middle East and North Africa          17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
def region(country):
    if country in ['Mauritius','Congo (Brazzaville)','Ivory Coast','Cameroon','Senegal','Ghana','Niger','Gambia','Benin','Guinea','South Africa','Gabon','Burkina Faso','Mozambique','Nigeria','Mali','Uganda','Liberia','Kenya','Namibia','Chad','Swaziland','Comoros','Ethiopia','Mauritania','Madagascar','Togo','Zambia', 'Sierra Leone','Burundi','Tanzania','Malawi','Lesotho','Botswana','Rwanda','Zimbabwe']:
        return 'Sub-Saharan Africa'
    elif country in df_west:
        return 'Western Europe'
    elif country in ['Costa Rica','Guatemala','Uruguay','Brazil','Mexico','Jamaica','Panama','Chile','El Salvador','Colombia','Nicaragua','Argentina','Honduras','Peru','Ecuador','Bolivia','Paraguay','Dominican Republic','Venezuela','Haiti']:
        return 'Latin America and Caribbean'
    elif country in ['Israel','Bahrain','United Arab Emirates','Saudi Arabia','Kuwait','Libya','Turkey','Morocco','Algeria','Iraq','Iran','Tunisia','Lebanon','Palestinian Territories','Jordan','Egypt','Yemen']:
        return 'Middle East and North Africa'
    elif country in ['Czech Republic','Slovenia','Kosovo','Slovakia','Lithuania','Estonia','Poland','Romania','Serbia','Latvia','Hungary','Croatia','Bosnia and Herzegovina','Montenegro', 'Bulgaria','Albania','North Macedonia']:
        return 'Central and Eastern Europe'
    elif country in ['Uzbekistan','Kazakhstan','Moldova','Kyrgyzstan','Belarus','Russia','Tajikistan','Armenia','Azerbaijan','Turkmenistan','Georgia','Ukraine']:
        return 'Commonwealth of Independent States'
    elif country in ['Singapore','Thailand','Philippines','Vietnam','Malaysia','Indonesia','Laos','Cambodia','Myanmar']:
        return 'Southeast Asia'
    elif country in ['Nepal','Maldives','Bangladesh','Pakistan','Sri Lanka','India','Afghanistan']:
        return 'South Asia'
    elif country in ['Taiwan Province of China','Japan','South Korea','Mongolia','Hong Kong S.A.R. of China','China']:
        return 'East Asia'
    elif country in ['New Zealand', 'Australia', 'Canada', 'United States']:
        return 'North America and ANZ'

# %%
history_df["Regional indicator"] = history_df["Country name"].apply(region)

# %%
history_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df1_2021
# Out:
#     Country name  Regional indicator  Life Ladder  Log GDP per capita  \
# 0        Finland      Western Europe        7.842              10.775
# 1        Denmark      Western Europe        7.620              10.933
# 2    Switzerland      Western Europe        7.571              11.117
# 3        Iceland      Western Europe        7.554              10.878
# 4    Netherlands      Western Europe        7.464              10.932
# ..           ...                 ...          ...                 ...
# 144      Lesotho  Sub-Saharan Africa        3.512               7.926
# 145     Botswana  Sub-Saharan Africa        3.467               9.782
# 146       Rwanda  Sub-Saharan Africa        3.415               7.676
# 147     Zimbabwe  Sub-Saharan Africa        3.145               7.943
# 148  Afghanistan          South Asia        2.523               7.695
#
#      Social support  Healthy life expectancy at birth  \
# 0             0.954                            72.000
# ...

# %%
df_son = pd.concat([history_df, df1_2021], ignore_index=True)

# %%
df_son
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 2093      Lesotho  2021        3.512               7.926           0.787
# 2094     Botswana  2021        3.467               9.782           0.784
# 2095       Rwanda  2021        3.415               7.676           0.552
# 2096     Zimbabwe  2021        3.145               7.943           0.750
# 2097  Afghanistan  2021        2.523               7.695           0.463
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_son[df_son["Regional indicator"] == "South Asia"].groupby("Country name")[["Life Ladder","Freedom to make life choices","Perceptions of corruption"]].describe()
# Out:
#              Life Ladder                                                      \
#                    count      mean       std    min      25%    50%      75%
# Country name
# Afghanistan         13.0  3.512231  0.769187  2.375  2.69400  3.724  3.98300
# Bangladesh          16.0  4.771375  0.292925  4.310  4.59425  4.692  5.03175
# India               16.0  4.432313  0.551463  3.249  4.14575  4.426  4.78725
# Maldives             2.0  5.198000  0.000000  5.198  5.19800  5.198  5.19800
# Nepal               15.0  4.728133  0.417833  3.809  4.50400  4.748  4.94600
# Pakistan            15.0  5.221933  0.433016  4.414  5.03300  5.225  5.51050
# Sri Lanka           14.0  4.309643  0.150113  3.977  4.21600  4.328  4.40250
#
#                     Freedom to make life choices            ...           \
#                 max                        count      mean  ...      75%
# Country name                                                ...
# ...

# %%
df_son[df_son["Country name"]=="Turkey"].sort_values(by="Social support", ascending=False)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1763       Turkey  2016        5.326              10.181           0.880
# 1764       Turkey  2017        5.607              10.238           0.876
# 1761       Turkey  2014        5.580              10.124           0.863
# 1767       Turkey  2020        4.862              10.219           0.857
# 1762       Turkey  2015        5.514              10.166           0.851
# 1765       Turkey  2018        5.186              10.251           0.847
# 2052       Turkey  2021        4.948              10.240           0.822
# 1753       Turkey  2005        4.719               9.809           0.820
# 1757       Turkey  2010        5.490               9.906           0.795
# 1760       Turkey  2013        4.888              10.091           0.795
# 1754       Turkey  2007        5.623               9.903           0.792
# 1766       Turkey  2019        4.872              10.246           0.792
# ...

# %%
df_son.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2098.000000  2098.000000         2062.000000     2085.000000
# mean   2013.768827     5.471402            9.373060        0.812709
# std       4.486449     1.112676            1.154247        0.118203
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.652250            8.470500        0.750000
# 50%    2014.000000     5.392000            9.462000        0.835000
# 75%    2018.000000     6.282500           10.360750        0.905000
# max    2021.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2043.000000                   2066.000000
# mean                          63.478503                      0.746094
# std                            7.468780                      0.140766
# min                           32.300000                      0.258000
# ...

# %%
def trust(corrupt):
    if corrupt >= 0.869000:
        return 'Low trust in institutions'
    elif corrupt > 0.801000 and corrupt < 0.869000:
        return 'Lower than normal level trust in institutions'
    elif corrupt > 0.688750 and corrupt <= 0.801000:
        return 'About the normal level trust in institutions'
    else:
        return 'High level trust in institutions'

# %%
df_son["Trust in institutions"] = df_son["Perceptions of corruption"].apply(trust)

# %%
df_son[df_son["Country name"] == "Pakistan"][["Country name","year","Perceptions of corruption","Trust in institutions"]]
# Out:
#      Country name  year  Perceptions of corruption  \
# 1311     Pakistan  2005                      0.844
# 1312     Pakistan  2007                      0.794
# 1313     Pakistan  2008                      0.848
# 1314     Pakistan  2009                      0.874
# 1315     Pakistan  2010                      0.852
# 1316     Pakistan  2011                      0.857
# 1317     Pakistan  2012                      0.842
# 1318     Pakistan  2013                      0.792
# 1319     Pakistan  2014                      0.677
# 1320     Pakistan  2015                      0.717
# 1321     Pakistan  2016                      0.793
# 1322     Pakistan  2017                      0.714
# 1323     Pakistan  2018                      0.799
# 1324     Pakistan  2019                      0.776
# 2053     Pakistan  2021                      0.787
#
#                               Trust in institutions
# 1311  Lower than normal level trust in institutions
# ...
